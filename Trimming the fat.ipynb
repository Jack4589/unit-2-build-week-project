# %%
import pandas as pd
import json

df = pd.read_json('bodies7days.json')
df.head()
# Out:
#           id          id64  bodyId                       name    type  \
# 0  288645500  3.242752e+17     9.0    Thaileia IO-F b44-7 B 1  Planet
# 1  288645501  3.602943e+16     1.0      Thaileia UP-W c18-2 A    Star
# 2  288645502  2.522087e+17     7.0      Byeia Euq JG-Y d206 7  Planet
# 3  288645503  1.801443e+17     5.0      Chrufee JT-G d11-10 4  Planet
# 4  288645504  3.963746e+17    11.0  Byeia Euq WX-S b58-26 7 a  Planet
#
#                     subType                        parents  distanceToArrival  \
# 0                  Icy body     [{'Star': 2}, {'Null': 0}]             245563
# 1    K (Yellow-Orange) Star                  [{'Null': 0}]                  0
# 2                  Icy body                  [{'Star': 0}]               3611
# 3  High metal content world                  [{'Star': 0}]               3860
# 4                  Icy body  [{'Planet': 10}, {'Star': 0}]               2573
#
#    isLandable   gravity  ...     age  spectralClass  luminosity  \
# ...

# %%
df = df[df['type'] == 'Star']

# %%
columns = list(df)

print(columns)
# Out:
# ['id', 'id64', 'bodyId', 'name', 'type', 'subType', 'parents', 'distanceToArrival', 'isLandable', 'gravity', 'earthMasses', 'radius', 'surfaceTemperature', 'surfacePressure', 'volcanismType', 'atmosphereType', 'atmosphereComposition', 'solidComposition', 'terraformingState', 'orbitalPeriod', 'semiMajorAxis', 'orbitalEccentricity', 'orbitalInclination', 'argOfPeriapsis', 'rotationalPeriod', 'rotationalPeriodTidallyLocked', 'axialTilt', 'updateTime', 'systemId', 'systemId64', 'systemName', 'isMainStar', 'isScoopable', 'age', 'spectralClass', 'luminosity', 'absoluteMagnitude', 'solarMasses', 'solarRadius', 'materials', 'rings', 'reserveLevel', 'belts']

# %%
df.drop(columns=['id',
        'id64'
       'name',
       'type',
       'parents',
       'distanceToArrival',
       'isLandable',
       'gravity',
       'earthMasses',
       'surfacePressure',
       'volcanismType',
        'atmosphereType',
        'atmosphereComposition',
        'solidComposition',
        'terraformingState',
        'orbitalPeriod',
        'semiMajorAxis',
        'orbitalEccentricity',
        'orbitalInclination',
        'argOfPeriapsis',
        'rotationalPeriodTidallyLocked',
        'axialTilt',
        'updateTime',
        'systemId',
        'systemId64',
        'systemName',
        'isScoopable',
        'materials',
        'rings',
        'reserveLevel',
        'belts'],
       inplace=True)

# %%
df.head()
# Out:
#             id64  bodyId                 subType  radius  surfaceTemperature  \
# 1   3.602943e+16     1.0  K (Yellow-Orange) Star     NaN                3715
# 18  1.441158e+17     4.0    L (Brown dwarf) Star     NaN                1766
# 19  1.080870e+17     3.0      M (Red dwarf) Star     NaN                2882
# 33  5.933759e+11     0.0      M (Red dwarf) Star     NaN                2557
# 57  1.495791e+14     0.0          F (White) Star     NaN                6594
#
#     rotationalPeriod  isMainStar     age spectralClass luminosity  \
# 1           2.519077         1.0  7344.0            K9         Va
# 18          1.221851         0.0  7344.0            L3          V
# 19          1.542847         0.0  7344.0            M4         Va
# 33          2.024965         1.0  2346.0            M6         Va
# 57          2.192743         1.0   244.0            F6        Vab
#
#     absoluteMagnitude  solarMasses  solarRadius
# 1            7.578094     0.527344     0.682587
# ...

# %%
df.head()
# Out:
#             id64  bodyId                 subType  radius  surfaceTemperature  \
# 1   3.602943e+16     1.0  K (Yellow-Orange) Star     NaN                3715
# 18  1.441158e+17     4.0    L (Brown dwarf) Star     NaN                1766
# 19  1.080870e+17     3.0      M (Red dwarf) Star     NaN                2882
# 33  5.933759e+11     0.0      M (Red dwarf) Star     NaN                2557
# 57  1.495791e+14     0.0          F (White) Star     NaN                6594
#
#     rotationalPeriod  isMainStar     age spectralClass luminosity  \
# 1           2.519077         1.0  7344.0            K9         Va
# 18          1.221851         0.0  7344.0            L3          V
# 19          1.542847         0.0  7344.0            M4         Va
# 33          2.024965         1.0  2346.0            M6         Va
# 57          2.192743         1.0   244.0            F6        Vab
#
#     absoluteMagnitude  solarMasses  solarRadius
# 1            7.578094     0.527344     0.682587
# ...

# %%
df.to_csv('trimmed.csv')
